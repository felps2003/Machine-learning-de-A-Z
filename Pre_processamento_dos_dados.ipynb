# %% [markdown]
# <a href="https://colab.research.google.com/github/felps2003/Machine-learning-de-A-Z/blob/main/Pre_processamento_dos_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 20.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.13.1
#     Uninstalling plotly-5.13.1:
#       Successfully uninstalled plotly-5.13.1
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
base_credit = pd.read_csv('/content/credit_risk_dataset.csv')

# %%
base_credit
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
base_credit.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
base_credit[base_credit['cb_person_default_on_file'] == 'Y']
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 4              24          54400                  RENT                8.0
# 21             25         137000                  RENT                9.0
# 24             22          80000                  RENT                3.0
# 26             21          11000              MORTGAGE                3.0
# ...           ...            ...                   ...                ...
# 32552          65          45900                  RENT                2.0
# 32555          51          80000                  RENT                3.0
# 32563          52          71520                  RENT                0.0
# 32568          60          49008                   OWN                5.0
# 32574          52          65004                  RENT                4.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
np.unique(base_credit['cb_person_default_on_file'], return_counts= True)
# Out:
# (array(['N', 'Y'], dtype=object), array([26836,  5745]))

# %%
sns.countplot(x = base_credit['cb_person_default_on_file']);

# %%
plt.hist( x = base_credit['person_age']);

# %%
plt.hist( x = base_credit['person_income']);

# %%
plt.hist(x = base_credit['loan_amnt']);

# %%
grafico = px.scatter_matrix(base_credit, dimensions=['person_age','person_income','loan_amnt'], color = 'cb_person_default_on_file')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
base_credit_new = base_credit[['person_age','person_income','loan_amnt','cb_person_default_on_file']]

# %%
base_credit_new = base_credit_new.rename(columns={'person_age':'age','person_income':'income','loan_amnt':'loan','cb_person_default_on_file':'default'})

# %%
base_credit_new[base_credit_new['age'] > 100]
# Out:
#        age   income   loan default
# 81     144   250000   4800       N
# 183    144   200000   6000       N
# 575    123    80004  20400       N
# 747    123    78000  20000       N
# 32297  144  6000000   5000       N

# %%
base_credit2 = base_credit_new.drop('age', axis = 1)
base_credit2
# Out:
#        income   loan default
# 0       59000  35000       Y
# 1        9600   1000       N
# 2        9600   5500       N
# 3       65500  35000       N
# 4       54400  35000       Y
# ...       ...    ...     ...
# 32576   53000   5800       N
# 32577  120000  17625       N
# 32578   76000  35000       N
# 32579  150000  15000       N
# 32580   42000   6475       N
#
# [32581 rows x 3 columns]

# %%
base_credit3 = base_credit_new.drop(base_credit_new[base_credit_new['age'] > 100].index)
base_credit3
# Out:
#        age  income   loan default
# 0       22   59000  35000       Y
# 1       21    9600   1000       N
# 2       25    9600   5500       N
# 3       23   65500  35000       N
# 4       24   54400  35000       Y
# ...    ...     ...    ...     ...
# 32576   57   53000   5800       N
# 32577   54  120000  17625       N
# 32578   65   76000  35000       N
# 32579   56  150000  15000       N
# 32580   66   42000   6475       N
#
# [32576 rows x 4 columns]

# %%
base_credit_new = base_credit_new.drop(base_credit_new[base_credit_new['age'] > 100].index)

# %%
base_credit_new.isnull()
# Out:
#          age  income   loan  default
# 0      False   False  False    False
# 1      False   False  False    False
# 2      False   False  False    False
# 3      False   False  False    False
# 4      False   False  False    False
# ...      ...     ...    ...      ...
# 32576  False   False  False    False
# 32577  False   False  False    False
# 32578  False   False  False    False
# 32579  False   False  False    False
# 32580  False   False  False    False
#
# [32576 rows x 4 columns]

# %%
base_credit_new.isnull().sum()
# Out:
# age        0
# income     0
# loan       0
# default    0
# dtype: int64

# %%
base_credit_new.loc[base_credit_new['default'] == 'Y', 'default'] = 1
base_credit_new.loc[base_credit_new['default'] == 'N', 'default'] = 0
base_credit_new
# Out:
#        age  income   loan default
# 0       22   59000  35000       1
# 1       21    9600   1000       0
# 2       25    9600   5500       0
# 3       23   65500  35000       0
# 4       24   54400  35000       1
# ...    ...     ...    ...     ...
# 32576   57   53000   5800       0
# 32577   54  120000  17625       0
# 32578   65   76000  35000       0
# 32579   56  150000  15000       0
# 32580   66   42000   6475       0
#
# [32576 rows x 4 columns]

# %%
x_credit = base_credit_new.iloc[:,0:3].values

# %%
x_credit
# Out:
# array([[    22,  59000,  35000],
#        [    21,   9600,   1000],
#        [    25,   9600,   5500],
#        ...,
#        [    65,  76000,  35000],
#        [    56, 150000,  15000],
#        [    66,  42000,   6475]])

# %%
type(x_credit)
# Out:
# numpy.ndarray

# %%
y_credit = base_credit_new.iloc[:,3].values

# %%
y_credit
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scaler_credit = StandardScaler()
x_credit = scaler_credit.fit_transform(x_credit)

# %%
x_credit
# Out:
# array([[-0.92153769, -0.13100311,  4.01957088],
#        [-1.08270079, -1.07134327, -1.35865285],
#        [-0.43804839, -1.07134327, -0.64682912],
#        ...,
#        [ 6.00847561,  0.19259573,  4.01957088],
#        [ 4.55800771,  1.60120243,  0.85590986],
#        [ 6.16963871, -0.45460195, -0.49260065]])
